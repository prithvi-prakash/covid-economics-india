# %%
import pandas as pd
import glob
import matplotlib.pyplot as plot
from scipy.stats import pearsonr
import matplotlib.pyplot as plt
import numpy as np

# %%
root = "./cleaned_datasets"

# %%
def readFolder(folder, time, col):
    readFolder = f"{root}/{folder}/{time}/*.csv"
    fileList = glob.glob(readFolder)
    myDict = {}
    for file in fileList:
        city = file.split("/")[-1].split(".")[0]
        mdf = pd.read_csv(file)
#         print(mdf.columns)
        myDict[city] = list(mdf[col])
    return myDict

# %%
preSentDict = readFolder("SentimentIndex", "pre", "sentimentRatio")
postSentDict = readFolder("SentimentIndex", "post", "sentimentRatio")

# %%
wpi = pd.read_csv("./Datasets/wpi_monthly_data.csv")

# %%
wpi.columns[96:]
# Out:
# Index(['INDX012019', 'INDX022019', 'INDX032019', 'INDX042019', 'INDX052019',
#        'INDX062019', 'INDX072019', 'INDX082019', 'INDX092019', 'INDX102019',
#        'INDX112019', 'INDX122019', 'INDX012020', 'INDX022020', 'INDX032020',
#        'INDX042020', 'INDX052020', 'INDX062020', 'INDX072020', 'INDX082020',
#        'INDX092020', 'INDX102020', 'INDX112020', 'INDX122020', 'INDX012021',
#        'INDX022021', 'INDX032021', 'INDX042021', 'INDX052021', 'INDX062021',
#        'INDX072021', 'INDX082021', 'INDX092021', 'INDX102021', 'INDX112021',
#        'INDX122021', 'INDX012022', 'INDX022022', 'INDX032022', 'INDX042022',
#        'INDX052022', 'INDX062022', 'INDX072022', 'INDX082022', 'INDX092022',
#        'INDX102022', 'INDX112022', 'INDX122022', 'INDX012023', 'INDX022023',
#        'INDX032023'],
#       dtype='object')

# %%
pre = ['INDX012019', 'INDX022019', 'INDX032019', 'INDX042019', 'INDX052019',
       'INDX062019', 'INDX072019', 'INDX082019', 'INDX092019', 'INDX102019',
       'INDX112019', 'INDX122019', 'INDX012020',]
post = ['INDX012020', 'INDX022020', 'INDX032020',
       'INDX042020', 'INDX052020', 'INDX062020', 'INDX072020', 'INDX082020',
       'INDX092020', 'INDX102020', 'INDX112020', 'INDX122020', 'INDX012021',
       'INDX022021', 'INDX032021', 'INDX042021', 'INDX052021', 'INDX062021',
       'INDX072021', 'INDX082021', 'INDX092021', 'INDX102021', 'INDX112021',
       'INDX122021', 'INDX012022', 'INDX022022', 'INDX032022', 'INDX042022',
       'INDX052022', 'INDX062022', 'INDX072022', 'INDX082022',]

# %%
pearsonr(wpi[wpi["COMM_NAME"]=="Wheat"][pre].to_numpy())
# Out:
# array([[154.8, 157.2, 155.5, 151.5, 150.7, 150.8, 153.4, 156.5, 158.3,
#         160.4, 164.5, 165.7, 168.7]])

# %%
commodity = "Petrol"
city = "Bangalore"

# %%
plt.plot(preSentDict[city])

# %%
plt.plot(wpi[wpi["COMM_NAME"]==commodity][pre].to_numpy()[0])

# %%
pearsonr(preSentDict[city], wpi[wpi["COMM_NAME"]==commodity][pre].to_numpy()[0])
# Out:
# (-0.16393615757511326, 0.5925349025600063)

# %%
pearsonr(postSentDict[city], wpi[wpi["COMM_NAME"]==commodity][post].to_numpy()[0])
# Out:
# (0.5185009394255435, 0.0023644111418949917)

# %%
wpi[wpi["COMM_NAME"]==commodity][pre].to_numpy()[0]
# Out:
# array([110.7, 108.2, 107.3, 107.3, 110.7, 108.3, 108.3, 110.7, 110. ,
#        110. , 110. , 117.9, 117.9])

# %%
(list(wpi["COMM_NAME"]))
# Out:
# ['ALL COMMODITIES',
#  'I    PRIMARY ARTICLES',
#  '(A).  FOOD ARTICLES',
#  'a.  FOOD GRAINS (CEREALS+PULSES)',
#  'a1. CEREALS',
#  'Paddy',
#  'Wheat',
#  'Jowar',
#  'Bajra',
#  'Maize',
#  'Barley',
#  'Ragi',
#  'a2. PULSES',
#  'Gram',
#  'Arhar',
#  'Moong',
#  'Masur',
#  'Urad',
#  'Peas/Chawali',
#  'Rajma',
#  'b.  FRUITS & VEGETABLES',
#  'b1. VEGETABLES',
#  'Potato',
#  'Sweet Potato',
#  'Onion',
#  'Tapioca',
#  'Ginger (Fresh)',
#  'Peas (Green)',
#  'Tomato',
#  'Cauliflower',
#  'Brinjal',
#  'Okra (Lady finger)',
#  'Cabbage',
#  'Carrot',
#  'Radish',
#  'Cucumber',
#  'Pointed gourd',
#  'Bitter gourd',
#  'Bottle gourd',
#  'Beans',
#  'Pumpkin',
#  'Drumstick',
#  'b2. FRUITS',
#  'Banana',
#  'Mango',
#  'Apple',
#  'Orange',
#  'Cashew nut',
#  'Coconut (Fresh)',
#  'Papaya',
#  'Grapes',
#  'Pineapple',
#  'Guava',
#  'Litchi',
#  'Lemon',
#  'Sapota',
#  'Mosambi (Sweet Orange)',
#  'Pomengranate',
#  'Amla',
#  'Jackfruit',
#  'Pear',
#  'Almonds',
#  'Walnut',
#  'c.  MILK',
#  'Milk',
#  'd.  EGGS,MEAT & FISH',
#  'Egg',
#  'Fish-Inland',
#  'Fish-Marine',
#  'Mutton',
#  'Beef and Buffalo Meat',
#  'Poultry Chicken',
#  'Pork',
#  'e.  CONDIMENTS & SPICES',
#  'Black Pepper',
#  'Chillies (Dry)',
#  'Turmeric',
#  'Cardamom',
#  'Ginger (Dry)',
#  'Betelnut/Arecanut',
#  'Cumin',
#  'Garlic',
#  'Coriander',
#  'Tamarind',
#  'f.  OTHER FOOD ARTICLES',
#  'Tea',
#  'Coffee',
#  'Betel Leaves',
#  'Sugarcane',
#  '(B).  NON-FOOD ARTICLES',
#  'a.  FIBRES',
#  'Raw Cotton',
#  'Raw Jute',
#  'Mesta',
#  'Raw Wool',
#  'Raw Silk',
#  'Coir Fibre',
#  'b.  OIL SEEDS',
#  'Groundnut Seed',
#  'Rape & Mustard Seed',
#  'Cotton Seed',
#  'Copra (Coconut)',
#  'Gingelly Seed (Sesamum)',
#  'Linseed',
#  'Castor Seed',
#  'Niger Seed',
#  'Safflower (Kardi Seed)',
#  'Sunflower',
#  'Soyabean',
#  'c.  OTHER NON-FOOD ARTICLES',
#  'Hides (Raw)',
#  'Skins (Raw)',
#  'Tanning Materials',
#  'Tobacco',
#  'Gaur Seed',
#  'Raw Rubber',
#  'Industrial wood',
#  'Fodder',
#  'd.   FLORICULTURE',
#  'Rose',
#  'Jasmine',
#  'Marigold',
#  '(C).  MINERALS',
#  'a.  METALLIC MINERALS',
#  'Bauxite',
#  'Chromite',
#  'Zinc Concentrate',
#  'Manganese Ore',
#  'Iron Ore',
#  'Copper Concentrate',
#  'Lead Concentrate',
#  'b.  OTHER MINERALS',
#  'Phosphorite',
#  'Limestone',
#  'Garnet',
#  'Sillimanite',
#  '(D). CRUDE PETROLEUM & NATURAL GAS',
#  'Crude Petroleum',
#  'Natural Gas',
#  'II FUEL & POWER',
#  '(A). COAL',
#  'a. Coking Coal',
#  'Coking Coal',
#  'b. Non-Coking Coal',
#  'a.) Non-Coking Coal G1 to G6 [GCV exceeding 5500 Kcal/kg.]',
#  'b.) Non-Coking Coal G7 to G14 [GCV 3100 Kcal/kg. to 5500 Kcal/kg.]',
#  'c.) Non-Coking Coal G15 to G17 [GCV < 3100 Kcal/kg.]',
#  'c. Lignite',
#  'Lignite',
#  '(B). MINERAL OILS',
#  'LPG',
#  'Petrol',
#  'Kerosene',
#  'ATF',
#  'HSD',
#  'Naphtha',
#  'Bitumen',
#  'Furnace Oil',
#  'Lube Oils',
#  'Petroleum Coke',
#  '(C). ELECTRICITY',
#  'Electricity',
#  'III   MANUFACTURED PRODUCTS',
#  '(A). MANUFACTURE OF FOOD PRODUCTS',
#  'a. Processing and preserving of meat',
#  'Buffalo meat, fresh/frozen',
#  'Meat of goat, fresh or chilled',
#  'Other meats, preserved/processed',
#  'Chicken/duck, dressed - fresh/frozen',
#  'b. Processing and preserving of fish, crustaceans and molluscs and products thereof',
#  'Shrimps/Prawns - Processed/Frozen',
#  'Fish frozen/canned/processed',
#  'c. Processing and preserving of fruit and vegetables',
#  'Fruit Juice including concentrates',
#  'Fruit pulp',
#  'Jams, jellies, marmalades and puree',
#  'Sauces of Vegetables (Tomato, Chilli, Soya & others)',
#  'd. Manufacture of vegetable and animal oils and fats',
#  'Vanaspati',
#  'Mustard Oil',
#  'Soyabean Oil',
#  'Sunflower Oil',
#  'Groundnut Oil',
#  'Castor Oil',
#  'Rice Bran Oil',
#  'Palm Oil',
#  'Rapeseed Oil',
#  'Copra oil',
#  'Cotton seed Oil',
#  'e. Manufacture of dairy products',
#  'Condensed Milk',
#  'Ghee',
#  'Butter',
#  'Ice cream',
#  'Powder Milk',
#  'f. Manufacture of grain mill products',
#  'Maida',
#  'Wheat flour (Atta)',
#  'Wheat Bran',
#  'Sooji (rawa )',
#  'Flour of cereals other than rice, wheat etc.',
#  'Gram powder (besan)',
#  'Rice, Non-basmati',
#  'Basmati rice',
#  'Rice products',
#  'g. Manufacture of starches and starch products',
#  'Vegetable starch',
#  'h. Manufacture of bakery products',
#  'Biscuit, cookies',
#  'Bread, buns & croissant',
#  'Cakes, pastries & muffins',
#  'i. Manufacture of sugar, molasses & honey',
#  'Sugar',
#  'Molasses',
#  'Bagasse',
#  'Gur',
#  'Honey',
#  'j. Manufacture of cocoa, chocolate and sugar confectionery',
#  'Chocolate & cocoa powder',
#  'Sugar confectionary',
#  'k. Manufacture of macaroni, noodles, couscous and similar farinaceous products',
#  'Noodles & similar extruded products',
#  'l. Manufacture of Tea & Coffee products',
#  'Processed Tea',
#  'Instant Coffee',
#  'Coffee powder with chicory',
#  'm. Manufacture of Processed condiments & salt',
#  'Spices (including mixed spices)',
#  'Salt',
#  'n. Manufacture of processed ready to eat food',
#  'Instant Food/Prepared meals based on vegetables',
#  'o. Manufacture of Health supplements',
#  'Corn Flake',
#  'Whey powder',
#  'p. Manufacture of prepared animal feeds',
#  'Gola & similar Cattle Feed',
#  'Rice Bran Extract',
#  'Soya preparations excluding oil',
#  'Cotton seed oil cake',
#  'Mustard oil cake',
#  '(B). MANUFACTURE OF BEVERAGES',
#  'a. Manufacture of wines & spirits',
#  'Spirits',
#  'Wine',
#  'Rectified spirit',
#  'b. Manufacture of malt liquors and malt',
#  'Beer',
#  'Country liquor',
#  'c. Manufacture of soft drinks; production of mineral waters and other bottled waters',
#  'Aerated drinks/soft drinks (incl. soft drink concentrates)',
#  'Bottled Mineral water',
#  '(C). MANUFACTURE OF TOBACCO PRODUCTS',
#  'a. Manufacture of tobacco products',
#  'Cigarette',
#  'Biri',
#  'Other tobacco products',
#  '(D). MANUFACTURE OF TEXTILES',
#  'a. Preparation and spinning of textile fibres',
#  'Cotton Yarn',
#  'Synthetic yarn',
#  'Viscose yarn',
#  'Woollen yarn',
#  'Texturised and twisted Yarn',
#  'b. Weaving & Finishing of textiles',
#  'Cotton woven cloth',
#  'Woollen woven cloth',
#  'Synthetic Fabric – Others',
#  'Cotton cloth (dyed, printed, or otherwise finished/processed)',
#  'Fabric, polyethylene',
#  'Fabrics/cloth, rayon',
#  'Jute sacking cloth/Gunny and hessian cloth',
#  'c. Manufacture of knitted and crocheted fabrics',
#  'Knitted fabrics of cotton',
#  'Cotton hosiery cloth',
#  'd. Manufacture of made-up textile articles, except apparel',
#  'Bed linen/Bed Spread',
#  'Blankets',
#  'Quilts',
#  'Cotton Dyed/printed textile',
#  'Cotton Towel',
#  'Terry Towel',
#  'Curtains',
#  'e. Manufacture of cordage, rope, twine and netting',
#  'Nylon rope',
#  'Cordage/ropes/twines of jute and coir',
#  'f. Manufacture of other textiles',
#  'Tyre cord fabric',
#  'Carpets and other floor coverings of textiles',
#  '(E). MANUFACTURE OF WEARING APPAREL',
#  'a. Manufacture of wearing apparel (woven), except fur apparel',
#  'Shirts/half shirts of cotton and/or man-made fibre',
#  'Trouser/pants made of cotton and/or man-made fibre',
#  'Men/Boys suits, coats and jackets',
#  'Leather garments incl. Jackets',
#  'b. Manufacture of knitted and crocheted apparel',
#  'Cardigans and pullovers, knitted',
#  'Shawls and scarves, knitted',
#  'Babies garments, knitted',
#  'Hosiery goods, others– cotton',
#  '(F). MANUFACTURE OF LEATHER AND RELATED PRODUCTS',
#  'a. Tanning and dressing of leather; dressing and dyeing of fur',
#  'Vegetable Tanned Leather',
#  'Chrome Tanned Leather',
#  'b. Manufacture of luggage, handbags, saddlery and harness',
#  'Travel goods, handbags, office bags, etc.',
#  'Belt & Other Articles of Leather',
#  'Harness, Saddles & Other related Items',
#  'Gloves of leather',
#  'c. Manufacture of footwear',
#  'Leather Shoe',
#  'Athletic/sport shoes',
#  'Canvas shoes',
#  'Plastic/PVC Chappals',
#  'Waterproof footwear',
#  '(G). MANUFACTURE OF WOOD AND OF PRODUCTS OF WOOD AND CORK  ',
#  'a. Saw milling and planing of wood',
#  'Timber/wooden plank, sawn/resawn',
#  'Wood cutting, processed/sized',
#  'Wooden splint',
#  'b. Manufacture of veneer sheets; manufacture of plywood, laminboard, particle board and other panels and boards',
#  'Plywood block boards',
#  'Particle Boards',
#  'Lamination wooden sheets/Veneer sheets',
#  'c. Manufacture of builders’ carpentry and joinery',
#  'Wooden panel',
#  'Wooden board (non-electrical)',
#  'd. Manufacture of wooden containers',
#  'Wooden block - compressed or not',
#  'Wooden box/crate',
#  '(H). MANUFACTURE OF PAPER AND PAPER PRODUCTS',
#  'a. Manufacture of pulp, paper and paperboard',
#  'Newsprint',
#  'Paper for printing & writing',
#  'Paper bag including craft paper bag',
#  'Base paper',
#  'Kraft paper',
#  'Laminated Paper',
#  'Card board',
#  'Tissue paper',
#  'Press board',
#  'Hard board',
#  'Bristle paper board',
#  'Poster paper',
#  'Pulp board',
#  'b. Manufacture of corrugated paper and paperboard and containers of paper and paperboard',
#  'Corrugated sheet box',
#  'Corrugated paper board',
#  'Card board box',
#  'Paper carton/box',
#  'c. Manufacture of other articles of paper and paperboard',
#  'Duplex paper',
#  'Map litho paper',
#  'Laminated plastic sheet',
#  '(I). PRINTING AND REPRODUCTION OF RECORDED MEDIA ',
#  'a. Printing',
#  'Newspaper',
#  'Journal/periodical',
#  'Printed labels/posters/calendars',
#  'Printed form & schedule',
#  'Printed Books',
#  'Hologram (3D)',
#  'Sticker plastic',
#  '(J). MANUFACTURE OF CHEMICALS AND CHEMICAL PRODUCTS',
#  'a. Manufacture of basic chemicals',
#  'Fatty acid',
#  'Organic Solvent',
#  'Dye stuff/dyes incl. dye intermediates and pigments/colours',
#  'Acetic acid and Its Derivatives',
#  'Aromatic chemicals',
#  'Caustic soda (sodium hydroxide)',
#  'Soda ash/washing soda',
#  'Carbon Black',
#  'Ethyl acetate',
#  'Mono Ethyl Glycol',
#  'Alkyl Benzene',
#  'Ethylene Oxide',
#  'Other Petrochemical Intermediates',
#  'Menthol',
#  'Camphor',
#  'Amine',
#  'Aniline (including pna, ona, ocpna)',
#  'Nitric Acid',
#  'Sulphuric Acid',
#  'Phosphoric acid',
#  'Liquid air & other gaseous products',
#  'Alcohols',
#  'Other Inorganic Chemicals',
#  'Phthalic anhydride',
#  'Ammonium nitrate',
#  'Catalysts',
#  'Sodium Silicate',
#  'b. Manufacture of fertilizers and nitrogen compounds',
#  'Urea',
#  'Di ammonium phosphate',
#  'Ammonium sulphate',
#  'Nitrogenous fertilizer, others',
#  'Mixed fertilizer',
#  'Ammonium phosphate',
#  'Ammonia gas',
#  'Ammonia liquid',
#  'Superphospate/Phosphatic fertilizer, others',
#  'c. Manufacture of plastic and synthetic rubber in primary form',
#  'Poly Propylene (PP)',
#  'Poly Vinyl Chloride (PVC)',
#  'Polyethylene',
#  'Polystyrene, expandable',
#  'Oleoresin',
#  'XLPE Compound',
#  'd. Manufacture of pesticides and other agrochemical products',
#  'Insecticide and Pesticide',
#  'Agro chemical formulation',
#  'Fungicide, liquid',
#  'e. Manufacture of paints, varnishes and similar coatings, printing ink and mastics',
#  'Paint',
#  'Varnish (all types)',
#  'Powder coating material',
#  'Printing ink',
#  'f. Manufacture of soap and detergents, cleaning and polishing preparations, perfumes and toilet preparations',
#  'Toilet soap',
#  'Detergent cake, washing soap cake/bar/powder',
#  'Organic surface active agent',
#  'Tooth paste/Tooth Powder',
#  'Agarbatti',
#  'Perfume/scent',
#  'Creams & Lotions for External Application',
#  'Face/Body Powder',
#  'Hair oil/Body Oil',
#  'Shampoo',
#  'Mosquito coil',
#  'g. Manufacture of other chemical products',
#  'Safety matches (match box)',
#  'Plasticizer',
#  'Polyester film(metalized)',
#  'Adhesive excluding gum',
#  'Adhesive tape (non-medicinal)',
#  'Gelatine',
#  'Hydrogen peroxide',
#  'Epoxy, liquid',
#  'Additive',
#  'Foundry chemical',
#  'Explosive',
#  'Rubber Chemicals',
#  'Organic chemicals',
#  'h. Manufacture of man-made fibres',
#  'Polyester chips or Polyethylene terepthalate (PET) chips',
#  'Acrylic fibre',
#  'Viscose staple fibre',
#  'Polyester fibre fabric',
#  '(K). MANUFACTURE OF PHARMACEUTICALS, MEDICINAL CHEMICAL AND BOTANICAL PRODUCTS',
#  'a. Manufacture of pharmaceuticals, medicinal chemical and botanical products',
#  'Anti inflammatory preparation',
#  'Anti cancer drugs',
#  'Antipyretic, analgesic, anti-inflammatory formulations',
#  'Vials/ampoule, glass, empty or filled',
#  'Anti-retroviral drugs for HIV treatment',
#  'Antidiabetic drug excluding insulin (i.e. tolbutam)',
#  'API & formulations of vitamins',
#  'Vaccine for hepatitis B',
#  'Ayurvedic medicaments',
#  'Simvastatin',
#  'Digestive enzymes and antacids',
#  'Vaccine for polio',
#  'Antibiotics & preparations thereof',
#  'Sulpha drugs',
#  'Anti allergic drugs',
#  'Antioxidants',
#  'Antiseptics and disinfectants',
#  'Cotton wool (medicinal)',
#  'Plastic capsules',
#  'Steroids and hormonal preparations (including anti-fungal preparations)',
#  'Anti-malarial drugs',
#  'IV fluids',
#  'Medical accessories',
#  '(L). MANUFACTURE OF RUBBER AND PLASTICS PRODUCTS',
#  'a. Manufacture of rubber tyres and tubes; retreading and rebuilding of rubber tyres',
#  'Motor Car Tyre',
#  'Tractor Tyre',
#  '2/3 wheeler Tyre',
#  'Medium & heavy commercial vehicle tyre',
#  'Solid Rubber Tyres/Wheels',
#  'Rubberized dipped fabric',
#  'Motor Car Tube',
#  'Rubber cloth/sheet',
#  '2/3 wheeler rubber tube',
#  'Medium & heavy commercial vehicle tube',
#  'Cycle/Cycle rickshaw tyre',
#  'b. Manufacture of other rubber products',
#  'V belt',
#  'Rubber moulded goods',
#  'Processed rubber',
#  'Rubber components & parts',
#  'Conveyer belt (fibre based)',
#  'Elastic webbing',
#  'Condoms',
#  'Rubber Crumb',
#  'Rubber Tread',
#  'Rubber tubes- not for tyres',
#  'c. Manufacture of plastics products',
#  'PVC fittings & other accessories',
#  'Polyester film (non-metalized)',
#  'Polypropylene film',
#  'Plastic film',
#  'Polythene film',
#  'Plastic furniture',
#  'Plastic bag',
#  'Plastic bottle',
#  'Thermocol',
#  'Plastic box/container',
#  'Plastic tube (flexible/non-flexible)',
#  'Plastic tape',
#  'Plastic components',
#  'Plastic tank',
#  'Acrylic/plastic sheet',
#  'Tooth brush',
#  'Plastic button',
#  '(M). MANUFACTURE OF OTHER NON-METALLIC MINERAL PRODUCTS',
#  'a. Manufacture of glass and glass products',
#  'Ordinary sheet glass',
#  'Toughened glass',
#  'Fibre glass incl. sheet',
#  'Glass bottle',
#  'Opthalmic lens',
#  'b. Manufacture of refractory products',
#  'Non ceramic tiles',
#  'Ceramic tiles (Vitrified tiles)',
#  'Plain bricks',
#  'c. Manufacture of clay building materials',
#  'Porcelain sanitary ware',
#  'd. Manufacture of other porcelain and ceramic products',
#  'Porcelain crockery',
#  'Electric insulating material',
#  'e. Manufacture of cement, lime and plaster',
#  'Lime and calcium carbonate',
#  'Clinker',
#  'Ordinary Portland cement',
#  'slag cement',
#  'Pozzolana cement',
#  'White cement',
#  'Cement superfine',
#  'f. Manufacture of articles of concrete, cement and plaster',
#  'Asbestos corrugated sheet',
#  'Marble Slab',
#  'Railway sleeper',
#  'Cement blocks (concrete)',
#  'Poles & posts of concrete',
#  'g. Cutting, shaping and finishing of stone',
#  'Granite',
#  'Stone, chip',
#  'h. Manufacture of other non-metallic mineral products',
#  'Graphite rod',
#  '(N). MANUFACTURE OF BASIC METALS',
#  'a. Inputs into steel making',
#  'Sponge Iron/Direct Reduced Iron (DRI)',
#  'Ferrochrome',
#  'Ferromanganese',
#  'Ferrosilicon',
#  'Silicomanganese',
#  'Other ferro alloys',
#  'b. Metallic iron',
#  'Pig Iron',
#  'c. Mild Steel - Semi Finished Steel',
#  'Mild Steel (MS) Blooms',
#  'MS Slabs',
#  'MS Pencil Ingots',
#  'd. Mild Steel -Long Products',
#  'MS Wire Rods',
#  'MS Bright Bars',
#  'Rails',
#  'Angles, Channels, Sections, steel (coated/not)',
#  'e. Mild Steel - Flat products',
#  'Hot Rolled (HR) Coils & Sheets, including Narrow Strip',
#  'Cold Rolled (CR) Coils & Sheets, including Narrow Strip',
#  'GP/GC sheet',
#  'Steel cables',
#  'f. Alloy steel other than Stainless Steel- Shapes',
#  'Alloy steel Wire rods',
#  'g. Stainless Steel - Semi Finished',
#  'Stainless Steel bars & rods, including flats',
#  'Stainless Steel Pencil Ingots/Billets/Slabs',
#  'Stainless Steel Coils, Strips & Sheets',
#  'h. Pipes & tubes',
#  'Galvanized iron pipes',
#  'Stainless steel tubes',
#  'i. Manufacture of non-ferrous metals incl. precious metals',
#  'Copper metal/Copper Rings',
#  'Zinc metal/zinc blocks',
#  'Aluminium metal',
#  'Aluminium powder',
#  'Lead ingots, bars, blocks, plates',
#  'Copper shapes - bars/rods/plates/strips',
#  'Aluminium alloys',
#  'Aluminium Disk and Circles',
#  'Alumnium Foil',
#  'Aluminium shapes - bars/rods/flats',
#  'Brass metal/sheet/coils',
#  'Aluminium ingot',
#  'j. Castings',
#  'Cast iron, castings',
#  'MS castings',
#  'Alloy steel castings',
#  'Aluminium castings',
#  'k. Forgings of steel',
#  'Steel forgings - rough',
#  '(O). MANUFACTURE OF FABRICATED METAL PRODUCTS, EXCEPT MACHINERY AND EQUIPMENT',
#  'a. Manufacture of structural metal products',
#  'Steel pipes, tubes & poles',
#  'Mild steel (MS) flats & sheets',
#  'Metal cutting tools & accessories',
#  'Jigs & Fixture',
#  'Steel structures',
#  'Bracket',
#  'b. Manufacture of tanks, reservoirs and containers of metal',
#  'Cylinders',
#  'Steel Container',
#  'Stainless steel tank',
#  'c. Manufacture of steam generators, except central heating hot water boilers',
#  'Boilers',
#  'Auxiliary plant for use with boilers',
#  'd. Forging, pressing, stamping and roll-forming of metal; powder metallurgy',
#  'Electrical stamping- Laminated or otherwise',
#  'Forged Steel Rings',
#  'e. Manufacture of cutlery, hand tools and general hardware',
#  'Stainless steel utensils',
#  'Stainless steel razor',
#  'Iron/steel hinges',
#  'Copper bolts, screws, nuts',
#  'Lock/padlock',
#  'f. Manufacture of other fabricated metal products',
#  'Bolts, screws, nuts & nails of Iron & steel',
#  'Hand tools',
#  'Iron/steel cap',
#  'Aluminium utensils',
#  'Sanitary fittings of Iron & Steel',
#  'Steel door',
#  'Hose pipes in set or otherwise',
#  'Pressure cooker',
#  'Steel drums and barrels',
#  '(P). MANUFACTURE OF COMPUTER, ELECTRONIC AND OPTICAL PRODUCTS',
#  'a. Manufacture of electronic components',
#  'Capacitors',
#  'UPS in Solid State Drives',
#  'Electronic Printed Circuit Board (PCB)/micro circuit',
#  'b. Manufacture of computers and peripheral equipment',
#  'Personal Computer (P.C.)',
#  'Laptops',
#  'Computer peripherals',
#  'c. Manufacture of communication equipment',
#  'Telephone sets including mobile hand sets',
#  'Modems',
#  'd. Manufacture of consumer electronics',
#  'Colour TV',
#  'Air conditioner',
#  'e. Manufacture of measuring, testing, navigating and control equipment',
#  'Meter (non-electrical)',
#  'f. Manufacture of watches and clocks',
#  'Watch',
#  'Scientific time keeping device',
#  'Clock',
#  'g. Manufacture of irradiation, electromedical and electrotherapeutic equipment',
#  'Electro-diagnostic apparatus, used in medical, surgical, dental or veterinary sciences',
#  'X-ray equipment',
#  'h. Manufacture of optical instruments and photographic equipment',
#  'Microscope',
#  'Sunglasses',
#  '(Q). MANUFACTURE OF ELECTRICAL EQUIPMENT',
#  'a. Manufacture of electric motors, generators, transformers and electricity distribution and control apparatus',
#  'Generators & Alternators',
#  'Cooling tower',
#  'Rotor/magneto rotor assembly',
#  'Transformer',
#  'A C Motor',
#  'Electric & other meters',
#  'Electric switch gear control/starter',
#  'Meter Panel',
#  'Amplifier',
#  'Electrical relay/conductor',
#  'Safety fuse',
#  'Multimeter',
#  'Generator parts',
#  'Electrical resistors (except heating resistors)',
#  'Solenoid valve',
#  'b. Manufacture of batteries and accumulators',
#  'Dry cells such as torch light batteries',
#  'Lead acid batteries for vehicles & other uses',
#  'Electric accumulators',
#  'Batteries',
#  'c. Manufacture of fibre optic cables for data transmission or live transmission of images',
#  'Fibre Optic Cables',
#  'd. Manufacture of other electronic and electric wires and cables',
#  'PVC Insulated Cable',
#  'Jelly Filled Cables',
#  'Electric Wires & Cables',
#  'ACSR Conductors',
#  'Aluminium/Alloy Conductor',
#  'Aluminium wire',
#  'Copper wire',
#  'Rubber Insulated Cables',
#  'Insulating & flexible wire',
#  'Connector/plug/socket/holder-electric',
#  'e. Manufacture of wiring devices, electric lighting & display equipment',
#  'Electric switch',
#  'Light fitting accessories',
#  'Flourescent tube',
#  'Incandescent Lamps',
#  'Electric filament type lamps',
#  'Electrical ballast & chokes',
#  'f. Manufacture of domestic appliances',
#  'Refrigerators',
#  'Electric Mixers/Grinders/Food Processors',
#  'Air Coolers',
#  'Geyser',
#  'Fan',
#  'Domestic gas stove',
#  'Washing Machines/Laundry Machines',
#  'Microwave oven',
#  'Electric heaters',
#  'g. Manufacture of other electrical equipment',
#  'Electric welding machine',
#  'Motors & other DC equipment',
#  'Insulator',
#  '(R). MANUFACTURE OF MACHINERY AND EQUIPMENT',
#  'a. Manufacture of engines and turbines, except aircraft, vehicle and two wheeler engines',
#  'Steam Turbines',
#  'Industrial valve',
#  'b. Manufacture of fluid power equipment',
#  'Injection pump',
#  'Hydraulic pump',
#  'Pneumatic tools',
#  'Water pump',
#  'c. Manufacture of other pumps, compressors, taps and valves',
#  'Centrifugal Pumps',
#  'Pump sets without motor',
#  'Air or vacuum pump',
#  'Air gas compressor including compressor for refrigerator',
#  'Gasket kit',
#  'd. Manufacture of bearings, gears, gearing and driving elements',
#  'Roller and ball bearings',
#  'Motor Starter',
#  'Clutches and shaft couplings',
#  'e. Manufacture of ovens, furnaces and furnace burners',
#  'Furnaces & Ovens',
#  'f. Manufacture of lifting and handling equipment',
#  'Cranes',
#  'Material handling, lifting and hoisting equipment',
#  'Hydraulic equipment',
#  'g. Manufacture of office machinery and equipment',
#  'Reprographic machine and scanners',
#  'h. Manufacture of other general-purpose machinery',
#  'Chillers',
#  'Air filters',
#  'Air conditioning plant',
#  'Filtration equipment',
#  'Conveyors - non-roller type',
#  'Oil pump',
#  'Deep freezers',
#  'Water purifier',
#  'i. Manufacture of agricultural and forestry machinery',
#  'Agricultural tractors',
#  'Harvesters',
#  'Agriculture implements',
#  'Threshers',
#  'Soil preparation & cultivation machinery (other than tractors)',
#  'j. Manufacture of metal-forming machinery and machine tools',
#  'Drilling Machine',
#  'Grinding or polishing machine',
#  'Lathes',
#  'Precision machinery equipment/Form tools',
#  'k. Manufacture of machinery for mining, quarrying and construction',
#  'Excavator',
#  'Dumper',
#  'Road roller',
#  'Loader',
#  'Mining, quarrying & metallurgical machinery/parts',
#  'Mixing machine',
#  'Concrete vibrator & mixture',
#  'Earth moving machinery',
#  'l. Manufacture of machinery for food, beverage and tobacco processing',
#  'Rice mill machinery',
#  'Pressure vessel and tank for fermentation & other food processing',
#  'Machinery used in the milling industry',
#  'Separator',
#  'Sugar Machinery',
#  'm. Manufacture of machinery for textile, apparel and leather production',
#  'Open end spinning machinery',
#  'Sewing Machines',
#  'Roller mill (Raymond)',
#  'Printing machinery',
#  'n. Manufacture of other special-purpose machinery',
#  'Machinery for plastic products - extruded',
#  'Moulding Machine',
#  'Chemical equipment & system',
#  'Pharmaceutical Machinery',
#  'Packing machine',
#  'Evaporator',
#  'o. Manufacture of renewable electricity generating equipment',
#  'Solar power system (solar panel & attachable equipment)',
#  'Windmill turbines (2500KW)',
#  '(S). MANUFACTURE OF MOTOR VEHICLES, TRAILERS AND SEMI-TRAILERS',
#  'a. Manufacture of motor vehicles',
#  'Light, medium & heavy commercial vehicles',
#  'Minibus/bus',
#  'Passenger vehicles',
#  'Chassis of different vehicle types',
#  'Body (for commercial motor vehicles)',
#  'b. Manufacture of parts and accessories for motor vehicles',
#  'Engine',
#  'Wheels/Wheels & parts',
#  'Shock absorbers',
#  'Shafts of all kinds',
#  'Axles of motor vehicles',
#  'Radiators & coolers',
#  'Piston ring/Piston and Compressor',
#  'Crankshaft',
#  'Silencer and Damper',
#  'Brake pad/brake liner/brake block/Brake rubber, others',
#  'Head lamp',
#  'Gear box and parts',
#  'Steering gear control system',
#  'Cylinder liners',
#  'Chain',
#  'Release valve',
#  'Filter element',
#  'Seat for motor vehicles',
#  'Ignition device',
#  '(T). MANUFACTURE OF OTHER TRANSPORT EQUIPMENT',
#  'a. Building of ships and floating structures',
#  'Fishing vessels, trawlers',
#  'Propellers & Blades of Boats/Ships',
#  'b. Manufacture of railway locomotives and rolling stock',
#  'Wagons',
#  'EMU coaches',
#  'Diesel/Electric locomotive',
#  'Railway brake gear',
#  'c. Manufacture of motor cycles',
#  'Motor cycles',
#  'Scooters',
#  'Auto rickshaw/Tempo/Matador/Three wheelers',
#  'd. Manufacture of bicycles and invalid carriages',
#  'Bicycles of all types',
#  'e. Manufacture of other transport equipment',
#  'Tanker',
#  '(U). MANUFACTURE OF FURNITURE',
#  'a. Manufacture of furniture',
#  'Wooden furniture',
#  'Plastic fixtures',
#  'Steel shutter gate',
#  'Iron/Steel Furniture',
#  'Hospital furniture',
#  'Foam and rubber mattress',
#  '(V). OTHER MANUFACTURING',
#  'a. Manufacture of jewellery and related articles',
#  'Gold & gold ornaments',
#  'Silver',
#  'b. Manufacture of musical instruments',
#  'Stringed musical instruments (incl. Santoor, Guitars, etc.)',
#  'c. Manufacture of sports goods',
#  'Sports goods of rubber (incl. balls)',
#  'Cricket ball',
#  'Cricket Bat',
#  'Football',
#  'Table Tennis Table',
#  'd. Manufacture of games and toys',
#  'Playing Cards',
#  'Carrom board',
#  'Plastic moulded-others toys',
#  'Non Mechanical Toys',
#  'e. Manufacture of medical and dental instruments and supplies',
#  'Intraocular Lens',
#  'IV FOOD INDEX']

# %%
wpi["COMM_NAME"]
# Out:
# 0                                        ALL COMMODITIES
# 1                                  I    PRIMARY ARTICLES
# 2                                    (A).  FOOD ARTICLES
# 3                       a.  FOOD GRAINS (CEREALS+PULSES)
# 4                                            a1. CEREALS
#                              ...
# 864                          Plastic moulded-others toys
# 865                                  Non Mechanical Toys
# 866    e. Manufacture of medical and dental instrumen...
# 867                                     Intraocular Lens
# 868                                        IV FOOD INDEX
# Name: COMM_NAME, Length: 869, dtype: object
