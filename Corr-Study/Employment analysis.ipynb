# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("./Datasets/employment.csv")

# %%
keyCols = df[df["Location Name"]=="Karnataka"].columns[9:]

# %%
x, y, z = df[df["Location Name"]=="Karnataka"][keyCols].to_numpy()

# %%
# plt.plot(x)
plt.plot(y)
plt.plot(z)
